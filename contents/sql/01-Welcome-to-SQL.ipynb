-- %% [markdown]
-- # Introduction to SQL
--
-- This environment uses SQLite to help you practice your queries.

-- %%
CREATE TABLE students (id INTEGER PRIMARY KEY, name TEXT, grade TEXT);
INSERT INTO students (name, grade) VALUES ('Alice', 'A'), ('Bob', 'B'), ('Charlie', 'A');
SELECT * FROM students;
